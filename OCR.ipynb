# %%
import cv2
import pytesseract

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img=cv2.imread("C:/Users/SHUBHIKA/Desktop/1.jpg")

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
pytesseract.pytesseract.tesseract_cmd="C:\\Program Files (x86)\\Tesseract-OCR\\tesseract.exe"

# %%
text = pytesseract.image_to_string(img)

# %%
print(text)
# Out:
# Murtaza's Worksho
# Robotics & Al
#
# 1 2 3 45 678910 1112 13 14

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/toDo.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text2= pytesseract.image_to_string(imgConverted) 
print(text2)
# Out:
#
#
# ___
# h
#
#
#
# pus [z. hr)
#
# %
#
# Can 4&0
# Guest
# then -
#
# (j Has
#
#
#
# T6 _ Po
#
# Owl/WE

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/2.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text2= pytesseract.image_to_string(imgConverted) 
print(text2)

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/3.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(imgConverted) 
print(text3)

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/google.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(img1) 
print(text3)

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/x.png")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(img1) 
print(text3)
# Out:
# OpenCV

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/4.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(img1) 
print(text3)
# Out:
# THE LAST CAR
#
# THAT PARKED HERE ||P
# IS STILL MISSING

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/y.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(img1) 
print(text3)

# %%
img1=cv2.imread("C:/Users/SHUBHIKA/Desktop/k.jpg")
imgConverted=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(imgConverted)

# %%
text3 = pytesseract.image_to_string(img1) 
print(text3)
# Out:
# |
#
# @» 1000
# Phefobook JL’J
# 10
#
# Finish
# Clem __ bathtoom
# 4 pose iprta a
#
# 1 Rotabaus _ flannte j ® om
# W C
# G Plan i ideot L_
# ray - -f £3
# 7
# -__ dess L_]
# & £3
#
# < Sho
# Ln fee mate
#
# W
#
# suave; -» swidtnd dates
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
# O
# )
# C3
# C
#
#
#
#
#
# U
# 8
